# %%
# !git pull
# Out:
# Already up to date.

# %%
from crategraph import Crate
crate = Crate("/Users/oreln/Downloads/EMEL")

# %%
crate
# Out:
# Graph(12751 entities, 26840 relationships, source='/Users/oreln/Downloads/EMEL')

# %%
crate.glimpse()

# %%
crate.summary()
# Out:
# === Graph Summary ===
# Source: /Users/oreln/Downloads/EMEL
# Entities: 12751 | Relationships: 26840
#
# Entity types:
#   Person                                             1706  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#   Entry                                              1613  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#   File, DigitalObject, thumbnail                     1559  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#   Place                                              1452  ▒▒▒▒▒▒▒▒▒▒▒▒▒
#   RepositoryObject, DigitalObject, digitised record  1370  ▒▒▒▒▒▒▒▒▒▒▒▒
#   +56 more
#
# Relationship types:
#   hasFile     3122  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#   dobject     3119  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#   preparedBy  2906  ▒▒▒▒▒▒▒▒▒▒▒▒▒▒
#   Entry       2441  ▒▒▒▒▒▒▒▒▒▒▒▒
#   Primary     2261  ▒▒▒▒▒▒▒▒▒▒▒
#   +10 more
#
# Most connected: Victoria (1011), VPRS 3183 City of Melbourne Town Clerk's Correspondence Files II (835), The Everyday War: World War I and the City of Melbourne (701)

# %%
crate.types
# Out:
# TypeRegistry([Also known as, Alternative spelling, ArchivalResource, Article, Birth name, Book, BookSection, Booksection, Catalogue, Concept, ... (63 total)])

# %%
people = crate.select(entity_types = ["Person"])
people
# Out:
# Graph(1706 entities, 0 relationships, source='/Users/oreln/Downloads/EMEL')

# %%
people = crate.visualise(filepath="people.html")
#people

# %%
people = crate.visualise(renderer="sigma", filepath="people.html")

# %%
# !open people.html

# %%
results = crate.search("Melbourne")
results
# Out:
# Graph(4418 entities, 7833 relationships, source='/Users/oreln/Downloads/EMEL')

# %%
crate.where
# Out:
# <bound method Graph.where of Graph(12751 entities, 26840 relationships, source='/Users/oreln/Downloads/EMEL')>

# %%
crate.select(entity_types=["Person"]).search("Melbourne")
# Out:
# Graph(1232 entities, 0 relationships, source='/Users/oreln/Downloads/EMEL')

# %%
crate.visualise
# Out:
# <bound method Graph.visualise of Graph(12751 entities, 26840 relationships, source='/Users/oreln/Downloads/EMEL')>
